# %% [markdown]
# This module extracts data from the following datasets:
# - CK+
# - RAVDESS Facial Landmark Tracking
# - Yale Face Database
#
# It is to be implemented using Convolutional Neural Networks in Keras with Tensorflow back-end.
# Training is to be done using Extended Cohn-Kanade Dataset.
#
# -Extract AUs from images using
