# %% [markdown]
# # Facial Emotion Recognition in Visual Data
#
# This notebook is a base module providing Emotional Awareness for an Embodied Conversational Agent developed in context of Affective Computing (CMPT 419 with Dr.Angelica Lim)
#
# The following Emotional Feature datasets are chosen for the project:<br>
# - Cohn Kanade Extended Dataset
# - Microsoft FER+ (2013)
#
# ### Outline:
# - CK+ Dataset Loading
# - Training a ConvNet using Keras
# - Evaluation
#
# - FER+ Dataset Loading
# - Training a ConvNet using Keras
# - Evaluation

# %%
import os
import pandas as pd
import numpy as np
import h5py

# Model-Related
import tensorflow as tf
from tensorflow.keras import layers

# Graphics and Plotting
import pydot, graphviz
import matplotlib.pyplot as plt 
import PIL
import seaborn as sns
sns.set()
sns.set_style(style = 'whitegrid')

# Data Preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# # CK+ Dataset: Loading

# %%
# Get the dataset as supplied
def getCK():
    ck_data = h5py.File('../Datasets/CK_data.h5', 'r')
    
    X = np.array(ck_data.get('data_pixel'))
    y = np.array(ck_data.get('data_label'))
    
    return X, y

# Splits into Train & Validation subsets
def splitTrainValidate(X, y, train_part):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = train_part)
    return X_train, y_train, X_test, y_test

# %%
# Get data & labels
X_CK, y_CK = getCK()

# %% [markdown]
# Decision to do a 75/25 train/validation split is due to a limited number of data points<br> (Labels are not equally proportionate in a dataset. See the Train/Validation Histogram below)

# %%
# Splitting a Dataset.
X_train, y_train, X_test, y_test = splitTrainValidate(X_CK, y_CK, 0.75)
y_test_labels = y_test

print("Training Data: ", X_train.shape)
print("Training Labels", y_train.shape)
print("Validation Data: ", X_test.shape)
print("Validation Labels: ",y_test.shape)
# Out:
# Training Data:  (735, 48, 48)
# Training Labels (735,)
# Validation Data:  (246, 48, 48)
# Validation Labels:  (246,)

# %%
emotion_labels_ck = ['Anger','Disgust','Fear','Happy','Sadness','Surprise', 'Contempt']

# %%
# Taking a Look at a Train-Validation Split
plt.figure(figsize = (9, 6) )
plt.xlabel(emotion_labels_ck, size = 14)
plt.ylabel('Number of Datapoints', size = 14)
plt.hist(y_CK, bins = 7, color = 'blue')
plt.hist(y_train, bins = 7, color = 'green');
plt.hist(y_test, bins = 7, color = 'orange');
plt.legend(['Total', 'Training', 'Validation'])
plt.title("Train / Validation Distribution", size = 16);

plt.show()

# %% [markdown]
# As we can see from the Histogram above, there is an insufficient amount of labeled data for Fear, Sadness and Contempt, meaning a trained model might not generalize well for previously unseen examples with these labels.

# %% [markdown]
# # CK+: ConvNet using Keras (TF2)

# %%
# Reshape and Normalize inputs to a CNN.
X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_train = np.float32(X_train) / X_train.max()
y_train = tf.keras.utils.to_categorical(y_train)

X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)
X_test = np.float32(X_test) / X_test.max()
y_test = tf.keras.utils.to_categorical(y_test)

# %%
model_ck = tf.keras.models.Sequential([
    
        tf.keras.layers.InputLayer(input_shape = (48, 48, 1)),
    
        # Dataset Augmentation
        tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
        tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
        tf.keras.layers.experimental.preprocessing.RandomZoom(0.25),
        tf.keras.layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
    
        tf.keras.layers.Conv2D(32, kernel_size = (4, 4), padding = "same"),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(32, kernel_size = (1, 1), padding = "same"),     
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(32, kernel_size = (4, 4), padding = "same"),     
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2)),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Conv2D(64, kernel_size = (3, 3), padding = "same"),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(64, kernel_size = (1, 1), padding = "same"),     
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(64, kernel_size = (3, 3), padding = "same"),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Conv2D(128, kernel_size = (2, 2), padding = "same"),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(128, kernel_size = (1, 1), padding = "same"),     
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(128, kernel_size = (2, 2), padding = "same"),     
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation = 'relu'),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(256, activation = 'relu'),    
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7, activation = 'softmax')
])

model_ck.compile(optimizer = tf.optimizers.Adam(), loss = 'categorical_crossentropy', metrics = [tf.keras.metrics.CategoricalAccuracy()])
model_ck_hist = model_ck.fit(X_train, y_train, batch_size = 10, epochs = 80, validation_data = (X_test, y_test))
# Out:
# Epoch 1/80
# 74/74 [==============================] - 7s 95ms/step - loss: 3.0895 - categorical_accuracy: 0.2054 - val_loss: 2.0941 - val_categorical_accuracy: 0.0976
# Epoch 2/80
# 74/74 [==============================] - 7s 93ms/step - loss: 1.9508 - categorical_accuracy: 0.2163 - val_loss: 2.1372 - val_categorical_accuracy: 0.0976
# Epoch 3/80
# 74/74 [==============================] - 7s 93ms/step - loss: 1.8958 - categorical_accuracy: 0.2476 - val_loss: 1.8898 - val_categorical_accuracy: 0.2805
# Epoch 4/80
# 74/74 [==============================] - 7s 99ms/step - loss: 1.8668 - categorical_accuracy: 0.2299 - val_loss: 2.5977 - val_categorical_accuracy: 0.0528
# Epoch 5/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8511 - categorical_accuracy: 0.2327 - val_loss: 2.4068 - val_categorical_accuracy: 0.0528
# Epoch 6/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8638 - categorical_accuracy: 0.2272 - val_loss: 2.1054 - val_categorical_accuracy: 0.0528
# Epoch 7/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8549 - categorical_accuracy: 0.2612 - val_loss: 2.3328 - val_categorical_accuracy: 0.0528
# Epoch 8/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8499 - categorical_accuracy: 0.2299 - val_loss: 2.4229 - val_categorical_accuracy: 0.0976
# Epoch 9/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8464 - categorical_accuracy: 0.2531 - val_loss: 1.9026 - val_categorical_accuracy: 0.2114
# Epoch 10/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.8191 - categorical_accuracy: 0.2803 - val_loss: 1.7892 - val_categorical_accuracy: 0.3699
# Epoch 11/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.7939 - categorical_accuracy: 0.3048 - val_loss: 1.8259 - val_categorical_accuracy: 0.3496
# Epoch 12/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.7607 - categorical_accuracy: 0.3224 - val_loss: 1.7280 - val_categorical_accuracy: 0.3740
# Epoch 13/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.7188 - categorical_accuracy: 0.3537 - val_loss: 1.3531 - val_categorical_accuracy: 0.5285
# Epoch 14/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.6733 - categorical_accuracy: 0.3565 - val_loss: 1.8013 - val_categorical_accuracy: 0.4431
# Epoch 15/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.7465 - categorical_accuracy: 0.3687 - val_loss: 1.3218 - val_categorical_accuracy: 0.4919
# Epoch 16/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.6625 - categorical_accuracy: 0.3864 - val_loss: 1.4023 - val_categorical_accuracy: 0.5366
# Epoch 17/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.6045 - categorical_accuracy: 0.4082 - val_loss: 1.9712 - val_categorical_accuracy: 0.4146
# Epoch 18/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.5913 - categorical_accuracy: 0.4014 - val_loss: 1.7809 - val_categorical_accuracy: 0.3699
# Epoch 19/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.6131 - categorical_accuracy: 0.4299 - val_loss: 1.6619 - val_categorical_accuracy: 0.4187
# Epoch 20/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.5380 - categorical_accuracy: 0.4340 - val_loss: 1.6592 - val_categorical_accuracy: 0.4350
# Epoch 21/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.5154 - categorical_accuracy: 0.4544 - val_loss: 1.2537 - val_categorical_accuracy: 0.5935
# Epoch 22/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.5459 - categorical_accuracy: 0.4422 - val_loss: 1.0184 - val_categorical_accuracy: 0.5894
# Epoch 23/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.4469 - categorical_accuracy: 0.4721 - val_loss: 1.5942 - val_categorical_accuracy: 0.4756
# Epoch 24/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.4735 - categorical_accuracy: 0.4544 - val_loss: 1.0694 - val_categorical_accuracy: 0.5650
# Epoch 25/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.4631 - categorical_accuracy: 0.4952 - val_loss: 2.1452 - val_categorical_accuracy: 0.3374
# Epoch 26/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.4665 - categorical_accuracy: 0.4735 - val_loss: 1.0117 - val_categorical_accuracy: 0.6057
# Epoch 27/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.3552 - categorical_accuracy: 0.5034 - val_loss: 1.1569 - val_categorical_accuracy: 0.5650
# Epoch 28/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.4315 - categorical_accuracy: 0.4748 - val_loss: 1.2853 - val_categorical_accuracy: 0.5325
# Epoch 29/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.3943 - categorical_accuracy: 0.4667 - val_loss: 1.5419 - val_categorical_accuracy: 0.4878
# Epoch 30/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.3602 - categorical_accuracy: 0.5116 - val_loss: 1.0132 - val_categorical_accuracy: 0.6220
# Epoch 31/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.3276 - categorical_accuracy: 0.4925 - val_loss: 0.9391 - val_categorical_accuracy: 0.6545
# Epoch 32/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.3361 - categorical_accuracy: 0.4939 - val_loss: 1.0698 - val_categorical_accuracy: 0.5894
# Epoch 33/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.3138 - categorical_accuracy: 0.5102 - val_loss: 1.0991 - val_categorical_accuracy: 0.6016
# Epoch 34/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.3122 - categorical_accuracy: 0.5184 - val_loss: 1.5758 - val_categorical_accuracy: 0.5203
# Epoch 35/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.2470 - categorical_accuracy: 0.5388 - val_loss: 1.1772 - val_categorical_accuracy: 0.5650
# Epoch 36/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.3647 - categorical_accuracy: 0.5075 - val_loss: 2.8337 - val_categorical_accuracy: 0.3740
# Epoch 37/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.2398 - categorical_accuracy: 0.5592 - val_loss: 2.4047 - val_categorical_accuracy: 0.4268
# Epoch 38/80
# 74/74 [==============================] - 8s 111ms/step - loss: 1.2759 - categorical_accuracy: 0.5497 - val_loss: 1.7960 - val_categorical_accuracy: 0.4837
# Epoch 39/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.2630 - categorical_accuracy: 0.5429 - val_loss: 0.9701 - val_categorical_accuracy: 0.6220
# Epoch 40/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.2442 - categorical_accuracy: 0.5293 - val_loss: 1.0394 - val_categorical_accuracy: 0.6138
# Epoch 41/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.2487 - categorical_accuracy: 0.5374 - val_loss: 0.8586 - val_categorical_accuracy: 0.6341
# Epoch 42/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.2563 - categorical_accuracy: 0.5197 - val_loss: 1.1295 - val_categorical_accuracy: 0.5488
# Epoch 43/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.2558 - categorical_accuracy: 0.5442 - val_loss: 1.2269 - val_categorical_accuracy: 0.5650
# Epoch 44/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.2167 - categorical_accuracy: 0.5415 - val_loss: 1.5055 - val_categorical_accuracy: 0.5772
# Epoch 45/80
# 74/74 [==============================] - 8s 109ms/step - loss: 1.1680 - categorical_accuracy: 0.5755 - val_loss: 1.5699 - val_categorical_accuracy: 0.5244
# Epoch 46/80
# 74/74 [==============================] - 8s 110ms/step - loss: 1.2524 - categorical_accuracy: 0.5537 - val_loss: 3.2197 - val_categorical_accuracy: 0.3415
# Epoch 47/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.2512 - categorical_accuracy: 0.5537 - val_loss: 1.0462 - val_categorical_accuracy: 0.6098
# Epoch 48/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.2155 - categorical_accuracy: 0.5429 - val_loss: 0.9646 - val_categorical_accuracy: 0.6138
# Epoch 49/80
# 74/74 [==============================] - 8s 104ms/step - loss: 1.1734 - categorical_accuracy: 0.5660 - val_loss: 0.9073 - val_categorical_accuracy: 0.6301
# Epoch 50/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.2024 - categorical_accuracy: 0.5633 - val_loss: 1.3988 - val_categorical_accuracy: 0.5488
# Epoch 51/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.1881 - categorical_accuracy: 0.5633 - val_loss: 0.8561 - val_categorical_accuracy: 0.6301
# Epoch 52/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1613 - categorical_accuracy: 0.5701 - val_loss: 0.9152 - val_categorical_accuracy: 0.5569
# Epoch 53/80
# 74/74 [==============================] - 8s 104ms/step - loss: 1.2198 - categorical_accuracy: 0.5633 - val_loss: 0.8543 - val_categorical_accuracy: 0.6667
# Epoch 54/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1933 - categorical_accuracy: 0.5687 - val_loss: 0.8947 - val_categorical_accuracy: 0.6301
# Epoch 55/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.2107 - categorical_accuracy: 0.5429 - val_loss: 1.1288 - val_categorical_accuracy: 0.5650
# Epoch 56/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.2298 - categorical_accuracy: 0.5578 - val_loss: 2.5477 - val_categorical_accuracy: 0.4878
# Epoch 57/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.1999 - categorical_accuracy: 0.5687 - val_loss: 0.8451 - val_categorical_accuracy: 0.6138
# Epoch 58/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.1911 - categorical_accuracy: 0.5891 - val_loss: 1.0806 - val_categorical_accuracy: 0.5854
# Epoch 59/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1351 - categorical_accuracy: 0.5864 - val_loss: 0.9923 - val_categorical_accuracy: 0.5935
# Epoch 60/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.1447 - categorical_accuracy: 0.5837 - val_loss: 1.0184 - val_categorical_accuracy: 0.5732
# Epoch 61/80
# 74/74 [==============================] - 8s 104ms/step - loss: 1.1351 - categorical_accuracy: 0.5701 - val_loss: 0.8251 - val_categorical_accuracy: 0.6545
# Epoch 62/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.1976 - categorical_accuracy: 0.5782 - val_loss: 0.9464 - val_categorical_accuracy: 0.6179
# Epoch 63/80
# 74/74 [==============================] - 8s 102ms/step - loss: 1.1540 - categorical_accuracy: 0.5728 - val_loss: 1.1991 - val_categorical_accuracy: 0.5935
# Epoch 64/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1161 - categorical_accuracy: 0.5810 - val_loss: 0.8472 - val_categorical_accuracy: 0.6545
# Epoch 65/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.1703 - categorical_accuracy: 0.5701 - val_loss: 0.9531 - val_categorical_accuracy: 0.5894
# Epoch 66/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1312 - categorical_accuracy: 0.5837 - val_loss: 0.8789 - val_categorical_accuracy: 0.6382
# Epoch 67/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.0552 - categorical_accuracy: 0.5755 - val_loss: 1.0307 - val_categorical_accuracy: 0.6098
# Epoch 68/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.1264 - categorical_accuracy: 0.6000 - val_loss: 1.4108 - val_categorical_accuracy: 0.5813
# Epoch 69/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.1099 - categorical_accuracy: 0.5905 - val_loss: 2.2198 - val_categorical_accuracy: 0.5081
# Epoch 70/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.0650 - categorical_accuracy: 0.5973 - val_loss: 1.1883 - val_categorical_accuracy: 0.5610
# Epoch 71/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.1379 - categorical_accuracy: 0.5891 - val_loss: 0.9590 - val_categorical_accuracy: 0.6179
# Epoch 72/80
# 74/74 [==============================] - 8s 108ms/step - loss: 1.0975 - categorical_accuracy: 0.5850 - val_loss: 0.7629 - val_categorical_accuracy: 0.6789
# Epoch 73/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.0858 - categorical_accuracy: 0.6150 - val_loss: 0.8953 - val_categorical_accuracy: 0.6585
# Epoch 74/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.0309 - categorical_accuracy: 0.6136 - val_loss: 0.7922 - val_categorical_accuracy: 0.6423
# Epoch 75/80
# 74/74 [==============================] - 8s 105ms/step - loss: 1.0959 - categorical_accuracy: 0.5782 - val_loss: 0.9118 - val_categorical_accuracy: 0.6220
# Epoch 76/80
# 74/74 [==============================] - 8s 104ms/step - loss: 1.0373 - categorical_accuracy: 0.6177 - val_loss: 0.7582 - val_categorical_accuracy: 0.6992
# Epoch 77/80
# 74/74 [==============================] - 8s 107ms/step - loss: 1.0128 - categorical_accuracy: 0.6122 - val_loss: 0.9193 - val_categorical_accuracy: 0.6911
# Epoch 78/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.0940 - categorical_accuracy: 0.6041 - val_loss: 0.8983 - val_categorical_accuracy: 0.6138
# Epoch 79/80
# 74/74 [==============================] - 8s 103ms/step - loss: 1.0290 - categorical_accuracy: 0.6109 - val_loss: 0.9248 - val_categorical_accuracy: 0.5813
# Epoch 80/80
# 74/74 [==============================] - 8s 106ms/step - loss: 1.0471 - categorical_accuracy: 0.5986 - val_loss: 0.7709 - val_categorical_accuracy: 0.6301

# %% [markdown]
# # CK+: Evaluation
# Let's now see what accuracy we ended up with after training for 80 epochs.

# %%
model_ck.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7709 - categorical_accuracy: 0.6301
# [0.770854115486145, 0.630081295967102]

# %%
# Training vs Validation Accuracies
plt.figure(figsize = (9, 6))

plt.plot(model_ck_hist.history['categorical_accuracy'])
plt.plot(model_ck_hist.history['val_categorical_accuracy']);
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('epoch', size = 14)
plt.ylabel('Accuracy Score', size = 14)
plt.title('Categorical Accuracy', size = 16)
plt.show()

# %%
# Training vs Validation Loss
plt.figure(figsize = (9, 6))

plt.plot(model_ck_hist.history['loss'])
plt.plot(model_ck_hist.history['val_loss']);
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('epoch', size = 14)
plt.ylabel('Loss', size = 14)
plt.title('Loss', size = 16)
plt.show()

# %%
# Wrongly Classified Images.
sns.set_style(style = 'white')

pred = model_ck.predict_classes(X_test);

figure = plt.figure(figsize = (16, 9))

i = 0
imgcount = 1
plt.title('Incorrectly Classified Images.')

while imgcount < 11:
    
    if(y_test[i].argmax() != pred[i]):
        figure.add_subplot(2, 5, imgcount)
        plt.imshow(X_test[i].reshape((48, 48)))
        imgcount += 1
        plt.title('Y: '+ emotion_labels_ck[pred[i]] +  ', Y_0: ' + emotion_labels_ck[y_test[i].argmax()])
        
    i += 1
    
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
# Plotting a confusion matrix.
ck_conf = tf.math.confusion_matrix(y_test_labels, pred, num_classes = 7)

plt.figure(figsize = (10, 6))
plt.imshow(ck_conf, cmap = 'CMRmap')
plt.ylabel('True Labels')
plt.xlabel('Predictions')
plt.colorbar()

plt.show()

# %% [markdown]
# Plotting a confusion matrix reveals the expected performance of a CNN trained on CK+ Dataset.
#
# It is evident that a model fails to classify completely or confuses the following Emotions:
# - Fear
# - Sadness
# - Contempt
# - Happy
# - Disgust
# - Anger
#
# Does relatively better on:
# - Surprise
#
# The unfortunate result, as evident on a post-split histogram, is likely due to poor variety of labeled data available.<br>
# After some trial, dataset Augmentation helps to improve the score, however it is unsufficient.

# %%
model_ck.save("ck_model_63.h5")

# %% [markdown]
# # FER+ Dataset: Loading

# %%
from io import StringIO

def parsePixels(pixelString):
    data = pixelString.split(" ")
        
    return data


# Loads the dataset, optionally saving the images.
def loadFER():
    fer_data = getFER()
    
# Transforms and saves the data Locally in a PNG format.

#     fer_training = fer_data[fer_data['Usage'] == 'Training']    
#     fer_validation_private = fer_data[fer_data['Usage'] == 'PrivateTest']
#     fer_validation_public = fer_data[fer_data['Usage'] == 'PublicTest']
    
#     # Save Training Images Locally
#     for idx, each in enumerate(fer_training['pixels']):
#         fer_training['pixels'].values[idx] =  np.asarray(fer_training['pixels'][idx]).reshape(48, 48)
#         img = PIL.Image.fromarray(fer_training['pixels'][idx])
#         img.save('../Datasets/FER2013/FER_TRAIN/' + 'fer_train_' + str(idx) + '.png')
        
#     # Save Training Labels
#     fer_training_y = fer_training['emotion']

#     # Save Validation Images (Private)
#     for idx, each in enumerate(fer_validation_private['pixels']):
#         fer_validation_private['pixels'].iloc[idx] = np.asarray(fer_validation_private['pixels'].iloc[idx]).reshape(48, 48)
#         img = PIL.Image.fromarray(fer_validation_private['pixels'].iloc[idx])
#         img.save('../Datasets/FER2013/FER_VAL_PRIVATE/' + 'fer_val_private_' + str(idx) + '.png')
        
#     # Save Validation Labels (Private)    
#     fer_validation_private_y = fer_validation_private['emotion']    
        
#     # Save Validation Images (Public)
#     for idx, each in enumerate(fer_validation_public['pixels']):
#         fer_validation_public['pixels'].iloc[idx] = np.asarray(fer_validation_public['pixels'].iloc[idx]).reshape(48, 48)
#         img = PIL.Image.fromarray(fer_validation_public['pixels'].iloc[idx])
#         img.save('../Datasets/FER2013/FER_VAL_PUBLIC/' + 'fer_val_public' + str(idx) + '.png')
        
#     # Save Validation Labels (Public)    
#     fer_validation_public_y = fer_validation_public['emotion']    
    
    # Prepare data
    pixels = fer_data['pixels'].tolist()
    parsed_pixels = []
    
    for pix_sequence in pixels:
        picture = parsePixels(pix_sequence)
        picture = np.asarray(picture, dtype = np.uint8).reshape(48, 48)
        parsed_pixels.append(picture)

    parsed_pixels = np.asarray(parsed_pixels)
    parsed_pixels = np.expand_dims(parsed_pixels, -1)
    
    emotion_labels = np.matrix(fer_data['emotion'])
    emotion_labels = emotion_labels.reshape(emotion_labels.shape[1], 1)
    
    return parsed_pixels, emotion_labels

# Get the raw data as supplied
def getFER():
    fer_data = pd.read_csv('../Datasets/fer2013.csv')
    
    return fer_data

# %%
# Get FER+ Dataset
# Uncomment The Local Saving Part in loadFER() to save images locally.
fer_pixels, fer_labels = loadFER()

# %% [markdown]
# I am using a 90/10 Train/Validation split. The FER+ dataset is large and has around 33 thousand images.<br>
# Having more data to train on is a goal, so only 10% for Validation will suffice.

# %%
# Performs the split
X_train, y_train, X_test, y_test = splitTrainValidate(fer_pixels, fer_labels, 0.9)

print("Training Data: ", X_train.shape)
print("Training Labels", y_train.shape)
print("Validation Data: ", X_test.shape)
print("Validation Labels: ",y_test.shape)
# Out:
# Training Data:  (32298, 48, 48, 1)
# Training Labels (32298, 1)
# Validation Data:  (3589, 48, 48, 1)
# Validation Labels:  (3589, 1)

# %%
emotion_labels_fer = ['Fear', 'Disgust', 'Anger' ,'Happiness' , 'Sadness', 'Surprise','Neutral']

# %%
plt.figure(figsize = (9, 6))
plt.hist(fer_labels, bins = 7, color = 'blue')
plt.hist(y_train, bins = 7, color = 'green')
plt.hist(y_test, bins = 7, color = 'orange')
plt.legend(['Total', 'Training', 'Validation'])

# %% [markdown]
# As we can see from the post-spit dataset, there an inadequately small amount of labeled data for emotion of Disgust.<br>
# We can not trust any predictions the model makes regarding this label.

# %% [markdown]
# # FER+: ConvNet using Keras (TF2)

# %%
# Prepare inputs.
X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_train = np.float32(X_train) / X_train.max()
y_train = tf.keras.utils.to_categorical(y_train)

X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)
X_test = np.float32(X_test) / X_test.max()
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# ConvNet Architecture and Training
model = tf.keras.models.Sequential([
    
        tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
        tf.keras.layers.experimental.preprocessing.RandomRotation(0.15),
        tf.keras.layers.experimental.preprocessing.RandomZoom(0.25),
        tf.keras.layers.experimental.preprocessing.RandomTranslation(0.2, 0.2),
    
        tf.keras.layers.Conv2D(32, kernel_size = (4, 4), padding = "same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(32, kernel_size = (1, 1), padding = "same"),     
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(32, kernel_size = (4, 4), padding = "same"),     
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Conv2D(64, kernel_size = (3, 3), padding = "same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(64, kernel_size = (1, 1), padding = "same"),     
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(64, kernel_size = (3, 3), padding = "same"),     
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(128, kernel_size = (1, 1), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Conv2D(256, kernel_size = (2, 2), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(256, kernel_size = (1, 1), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(256, kernel_size = (2, 2), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (1, 1)),
        tf.keras.layers.Dropout(0.5),
    
        tf.keras.layers.Conv2D(512, kernel_size = (2, 2), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(512, kernel_size = (1, 1), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(512, kernel_size = (2, 2), padding = "same"),    
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPool2D(pool_size = (2, 2), strides = (2, 2)),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation = 'relu'),
        tf.keras.layers.Dense(512, activation = 'relu'),
    
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7, activation = 'softmax')
])

model.compile(optimizer = tf.optimizers.Adam(), loss = 'categorical_crossentropy', metrics = [tf.keras.metrics.CategoricalAccuracy()])
model_log = model.fit(X_train, y_train, batch_size = 64, epochs = 100, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.8902 - categorical_accuracy: 0.2332 - val_loss: 1.8555 - val_categorical_accuracy: 0.2527
# Epoch 2/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.8095 - categorical_accuracy: 0.2455 - val_loss: 1.8229 - val_categorical_accuracy: 0.2527
# Epoch 3/100
# 505/505 [==============================] - 367s 727ms/step - loss: 1.8021 - categorical_accuracy: 0.2471 - val_loss: 1.8435 - val_categorical_accuracy: 0.2502
# Epoch 4/100
# 505/505 [==============================] - 367s 726ms/step - loss: 1.7992 - categorical_accuracy: 0.2500 - val_loss: 1.8602 - val_categorical_accuracy: 0.2349
# Epoch 5/100
# 505/505 [==============================] - 368s 729ms/step - loss: 1.7917 - categorical_accuracy: 0.2528 - val_loss: 1.8085 - val_categorical_accuracy: 0.2527
# Epoch 6/100
# 505/505 [==============================] - 368s 729ms/step - loss: 1.7833 - categorical_accuracy: 0.2586 - val_loss: 1.8386 - val_categorical_accuracy: 0.2396
# Epoch 7/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.7631 - categorical_accuracy: 0.2738 - val_loss: 1.8193 - val_categorical_accuracy: 0.2522
# Epoch 8/100
# 505/505 [==============================] - 370s 732ms/step - loss: 1.7383 - categorical_accuracy: 0.2852 - val_loss: 1.7590 - val_categorical_accuracy: 0.2664
# Epoch 9/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.6988 - categorical_accuracy: 0.3062 - val_loss: 1.5878 - val_categorical_accuracy: 0.3527
# Epoch 10/100
# 505/505 [==============================] - 370s 732ms/step - loss: 1.6584 - categorical_accuracy: 0.3318 - val_loss: 1.7796 - val_categorical_accuracy: 0.2728
# Epoch 11/100
# 505/505 [==============================] - 370s 732ms/step - loss: 1.6078 - categorical_accuracy: 0.3635 - val_loss: 1.5193 - val_categorical_accuracy: 0.4126
# Epoch 12/100
# 505/505 [==============================] - 370s 733ms/step - loss: 1.5795 - categorical_accuracy: 0.3837 - val_loss: 1.5180 - val_categorical_accuracy: 0.4269
# Epoch 13/100
# 505/505 [==============================] - 369s 732ms/step - loss: 1.5447 - categorical_accuracy: 0.3997 - val_loss: 1.4797 - val_categorical_accuracy: 0.4093
# Epoch 14/100
# 505/505 [==============================] - 370s 734ms/step - loss: 1.5148 - categorical_accuracy: 0.4143 - val_loss: 1.3764 - val_categorical_accuracy: 0.4609
# Epoch 15/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.4963 - categorical_accuracy: 0.4218 - val_loss: 1.3746 - val_categorical_accuracy: 0.4645
# Epoch 16/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.4724 - categorical_accuracy: 0.4342 - val_loss: 1.5208 - val_categorical_accuracy: 0.4079
# Epoch 17/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.4535 - categorical_accuracy: 0.4442 - val_loss: 1.3457 - val_categorical_accuracy: 0.4831
# Epoch 18/100
# 505/505 [==============================] - 368s 729ms/step - loss: 1.4337 - categorical_accuracy: 0.4524 - val_loss: 1.3000 - val_categorical_accuracy: 0.5102
# Epoch 19/100
# 505/505 [==============================] - 371s 734ms/step - loss: 1.4159 - categorical_accuracy: 0.4593 - val_loss: 1.2756 - val_categorical_accuracy: 0.5166
# Epoch 20/100
# 505/505 [==============================] - 373s 740ms/step - loss: 1.4018 - categorical_accuracy: 0.4599 - val_loss: 1.3537 - val_categorical_accuracy: 0.4784
# Epoch 21/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.3970 - categorical_accuracy: 0.4615 - val_loss: 1.3081 - val_categorical_accuracy: 0.5077
# Epoch 22/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.3852 - categorical_accuracy: 0.4664 - val_loss: 1.2834 - val_categorical_accuracy: 0.5065
# Epoch 23/100
# 505/505 [==============================] - 370s 733ms/step - loss: 1.3791 - categorical_accuracy: 0.4682 - val_loss: 1.3011 - val_categorical_accuracy: 0.5032
# Epoch 24/100
# 505/505 [==============================] - 370s 733ms/step - loss: 1.3693 - categorical_accuracy: 0.4746 - val_loss: 1.2955 - val_categorical_accuracy: 0.5082
# Epoch 25/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.3586 - categorical_accuracy: 0.4761 - val_loss: 1.2506 - val_categorical_accuracy: 0.5233
# Epoch 26/100
# 505/505 [==============================] - 369s 731ms/step - loss: 1.3452 - categorical_accuracy: 0.4858 - val_loss: 1.2798 - val_categorical_accuracy: 0.5082
# Epoch 27/100
# 505/505 [==============================] - 366s 726ms/step - loss: 1.3451 - categorical_accuracy: 0.4843 - val_loss: 1.3487 - val_categorical_accuracy: 0.4790
# Epoch 28/100
# 505/505 [==============================] - 373s 739ms/step - loss: 1.3393 - categorical_accuracy: 0.4827 - val_loss: 1.2568 - val_categorical_accuracy: 0.5205
# Epoch 29/100
# 505/505 [==============================] - 370s 733ms/step - loss: 1.3336 - categorical_accuracy: 0.4902 - val_loss: 1.2478 - val_categorical_accuracy: 0.5191
# Epoch 30/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.3260 - categorical_accuracy: 0.4906 - val_loss: 1.2528 - val_categorical_accuracy: 0.5116
# Epoch 31/100
# 505/505 [==============================] - 377s 747ms/step - loss: 1.3200 - categorical_accuracy: 0.4958 - val_loss: 1.2571 - val_categorical_accuracy: 0.5230
# Epoch 32/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.3186 - categorical_accuracy: 0.4954 - val_loss: 1.2305 - val_categorical_accuracy: 0.5319
# Epoch 33/100
# 505/505 [==============================] - 374s 741ms/step - loss: 1.3140 - categorical_accuracy: 0.4984 - val_loss: 1.2082 - val_categorical_accuracy: 0.5350
# Epoch 34/100
# 505/505 [==============================] - 375s 743ms/step - loss: 1.3089 - categorical_accuracy: 0.4999 - val_loss: 1.2251 - val_categorical_accuracy: 0.5143
# Epoch 35/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.3042 - categorical_accuracy: 0.5009 - val_loss: 1.3210 - val_categorical_accuracy: 0.4960
# Epoch 36/100
# 505/505 [==============================] - 374s 741ms/step - loss: 1.3006 - categorical_accuracy: 0.5007 - val_loss: 1.1906 - val_categorical_accuracy: 0.5386
# Epoch 37/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2960 - categorical_accuracy: 0.5051 - val_loss: 1.2294 - val_categorical_accuracy: 0.5163
# Epoch 38/100
# 505/505 [==============================] - 373s 740ms/step - loss: 1.2898 - categorical_accuracy: 0.5059 - val_loss: 1.2432 - val_categorical_accuracy: 0.5355
# Epoch 39/100
# 505/505 [==============================] - 373s 739ms/step - loss: 1.2875 - categorical_accuracy: 0.5064 - val_loss: 1.2073 - val_categorical_accuracy: 0.5422
# Epoch 40/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2836 - categorical_accuracy: 0.5088 - val_loss: 1.2392 - val_categorical_accuracy: 0.5074
# Epoch 41/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.2842 - categorical_accuracy: 0.5052 - val_loss: 1.1845 - val_categorical_accuracy: 0.5400
# Epoch 42/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2795 - categorical_accuracy: 0.5065 - val_loss: 1.2235 - val_categorical_accuracy: 0.5355
# Epoch 43/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.2784 - categorical_accuracy: 0.5118 - val_loss: 1.1794 - val_categorical_accuracy: 0.5405
# Epoch 44/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2753 - categorical_accuracy: 0.5113 - val_loss: 1.1835 - val_categorical_accuracy: 0.5517
# Epoch 45/100
# 505/505 [==============================] - 371s 736ms/step - loss: 1.2712 - categorical_accuracy: 0.5154 - val_loss: 1.2201 - val_categorical_accuracy: 0.5364
# Epoch 46/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.2684 - categorical_accuracy: 0.5145 - val_loss: 1.2207 - val_categorical_accuracy: 0.5316
# Epoch 47/100
# 505/505 [==============================] - 374s 741ms/step - loss: 1.2654 - categorical_accuracy: 0.5183 - val_loss: 1.2098 - val_categorical_accuracy: 0.5411
# Epoch 48/100
# 505/505 [==============================] - 373s 739ms/step - loss: 1.2639 - categorical_accuracy: 0.5188 - val_loss: 1.2056 - val_categorical_accuracy: 0.5414
# Epoch 49/100
# 505/505 [==============================] - 371s 734ms/step - loss: 1.2633 - categorical_accuracy: 0.5176 - val_loss: 1.2118 - val_categorical_accuracy: 0.5397
# Epoch 50/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.2590 - categorical_accuracy: 0.5190 - val_loss: 1.1673 - val_categorical_accuracy: 0.5603
# Epoch 51/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.2529 - categorical_accuracy: 0.5250 - val_loss: 1.1918 - val_categorical_accuracy: 0.5475
# Epoch 52/100
# 505/505 [==============================] - 372s 738ms/step - loss: 1.2553 - categorical_accuracy: 0.5219 - val_loss: 1.1897 - val_categorical_accuracy: 0.5531
# Epoch 53/100
# 505/505 [==============================] - 378s 748ms/step - loss: 1.2486 - categorical_accuracy: 0.5247 - val_loss: 1.1760 - val_categorical_accuracy: 0.5461
# Epoch 54/100
# 505/505 [==============================] - 375s 742ms/step - loss: 1.2513 - categorical_accuracy: 0.5241 - val_loss: 1.1810 - val_categorical_accuracy: 0.5439
# Epoch 55/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2427 - categorical_accuracy: 0.5283 - val_loss: 1.1803 - val_categorical_accuracy: 0.5456
# Epoch 56/100
# 505/505 [==============================] - 376s 744ms/step - loss: 1.2410 - categorical_accuracy: 0.5263 - val_loss: 1.1428 - val_categorical_accuracy: 0.5673
# Epoch 57/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2433 - categorical_accuracy: 0.5249 - val_loss: 1.1580 - val_categorical_accuracy: 0.5592
# Epoch 58/100
# 505/505 [==============================] - 371s 734ms/step - loss: 1.2356 - categorical_accuracy: 0.5300 - val_loss: 1.1808 - val_categorical_accuracy: 0.5464
# Epoch 59/100
# 505/505 [==============================] - 375s 742ms/step - loss: 1.2359 - categorical_accuracy: 0.5282 - val_loss: 1.1670 - val_categorical_accuracy: 0.5542
# Epoch 60/100
# 505/505 [==============================] - 377s 746ms/step - loss: 1.2372 - categorical_accuracy: 0.5303 - val_loss: 1.1689 - val_categorical_accuracy: 0.5642
# Epoch 61/100
# 505/505 [==============================] - 376s 744ms/step - loss: 1.2350 - categorical_accuracy: 0.5298 - val_loss: 1.1521 - val_categorical_accuracy: 0.5598
# Epoch 62/100
# 505/505 [==============================] - 375s 742ms/step - loss: 1.2372 - categorical_accuracy: 0.5312 - val_loss: 1.1506 - val_categorical_accuracy: 0.5598
# Epoch 63/100
# 505/505 [==============================] - 374s 741ms/step - loss: 1.2297 - categorical_accuracy: 0.5327 - val_loss: 1.1312 - val_categorical_accuracy: 0.5759
# Epoch 64/100
# 505/505 [==============================] - 374s 741ms/step - loss: 1.2304 - categorical_accuracy: 0.5358 - val_loss: 1.1665 - val_categorical_accuracy: 0.5614
# Epoch 65/100
# 505/505 [==============================] - 373s 739ms/step - loss: 1.2231 - categorical_accuracy: 0.5382 - val_loss: 1.1416 - val_categorical_accuracy: 0.5665
# Epoch 66/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2220 - categorical_accuracy: 0.5402 - val_loss: 1.1376 - val_categorical_accuracy: 0.5704
# Epoch 67/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2224 - categorical_accuracy: 0.5390 - val_loss: 1.1525 - val_categorical_accuracy: 0.5731
# Epoch 68/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.2196 - categorical_accuracy: 0.5370 - val_loss: 1.1233 - val_categorical_accuracy: 0.5731
# Epoch 69/100
# 505/505 [==============================] - 373s 739ms/step - loss: 1.2147 - categorical_accuracy: 0.5413 - val_loss: 1.1418 - val_categorical_accuracy: 0.5676
# Epoch 70/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2174 - categorical_accuracy: 0.5403 - val_loss: 1.1581 - val_categorical_accuracy: 0.5570
# Epoch 71/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.2173 - categorical_accuracy: 0.5414 - val_loss: 1.1245 - val_categorical_accuracy: 0.5706
# Epoch 72/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.2089 - categorical_accuracy: 0.5408 - val_loss: 1.1552 - val_categorical_accuracy: 0.5659
# Epoch 73/100
# 505/505 [==============================] - 372s 736ms/step - loss: 1.2143 - categorical_accuracy: 0.5405 - val_loss: 1.1316 - val_categorical_accuracy: 0.5740
# Epoch 74/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.2134 - categorical_accuracy: 0.5402 - val_loss: 1.1240 - val_categorical_accuracy: 0.5717
# Epoch 75/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2092 - categorical_accuracy: 0.5422 - val_loss: 1.1569 - val_categorical_accuracy: 0.5600
# Epoch 76/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.2010 - categorical_accuracy: 0.5461 - val_loss: 1.1290 - val_categorical_accuracy: 0.5768
# Epoch 77/100
# 505/505 [==============================] - 369s 730ms/step - loss: 1.2046 - categorical_accuracy: 0.5448 - val_loss: 1.1471 - val_categorical_accuracy: 0.5712
# Epoch 78/100
# 505/505 [==============================] - 371s 734ms/step - loss: 1.2039 - categorical_accuracy: 0.5429 - val_loss: 1.1099 - val_categorical_accuracy: 0.5821
# Epoch 79/100
# 505/505 [==============================] - 372s 738ms/step - loss: 1.1987 - categorical_accuracy: 0.5472 - val_loss: 1.1153 - val_categorical_accuracy: 0.5868
# Epoch 80/100
# 505/505 [==============================] - 374s 742ms/step - loss: 1.2050 - categorical_accuracy: 0.5477 - val_loss: 1.1144 - val_categorical_accuracy: 0.5809
# Epoch 81/100
# 505/505 [==============================] - 373s 738ms/step - loss: 1.1991 - categorical_accuracy: 0.5494 - val_loss: 1.1566 - val_categorical_accuracy: 0.5684
# Epoch 82/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.2022 - categorical_accuracy: 0.5479 - val_loss: 1.1337 - val_categorical_accuracy: 0.5754
# Epoch 83/100
# 505/505 [==============================] - 375s 742ms/step - loss: 1.2001 - categorical_accuracy: 0.5447 - val_loss: 1.1199 - val_categorical_accuracy: 0.5751
# Epoch 84/100
# 505/505 [==============================] - 374s 740ms/step - loss: 1.1926 - categorical_accuracy: 0.5466 - val_loss: 1.1296 - val_categorical_accuracy: 0.5748
# Epoch 85/100
# 505/505 [==============================] - 371s 736ms/step - loss: 1.1919 - categorical_accuracy: 0.5511 - val_loss: 1.1085 - val_categorical_accuracy: 0.5868
# Epoch 86/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.1970 - categorical_accuracy: 0.5480 - val_loss: 1.0982 - val_categorical_accuracy: 0.5904
# Epoch 87/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.1892 - categorical_accuracy: 0.5511 - val_loss: 1.1293 - val_categorical_accuracy: 0.5829
# Epoch 88/100
# 505/505 [==============================] - 371s 734ms/step - loss: 1.1926 - categorical_accuracy: 0.5482 - val_loss: 1.1091 - val_categorical_accuracy: 0.5857
# Epoch 89/100
# 505/505 [==============================] - 371s 735ms/step - loss: 1.1868 - categorical_accuracy: 0.5532 - val_loss: 1.1378 - val_categorical_accuracy: 0.5759
# Epoch 90/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.1904 - categorical_accuracy: 0.5537 - val_loss: 1.1036 - val_categorical_accuracy: 0.5952
# Epoch 91/100
# 505/505 [==============================] - 372s 737ms/step - loss: 1.1908 - categorical_accuracy: 0.5536 - val_loss: 1.0995 - val_categorical_accuracy: 0.5865
# Epoch 92/100
# 505/505 [==============================] - 377s 747ms/step - loss: 1.1849 - categorical_accuracy: 0.5556 - val_loss: 1.1090 - val_categorical_accuracy: 0.5865
# Epoch 93/100
# 505/505 [==============================] - 376s 745ms/step - loss: 1.1914 - categorical_accuracy: 0.5540 - val_loss: 1.0929 - val_categorical_accuracy: 0.5890
# Epoch 94/100
# 505/505 [==============================] - 377s 747ms/step - loss: 1.1848 - categorical_accuracy: 0.5532 - val_loss: 1.0959 - val_categorical_accuracy: 0.5798
# Epoch 95/100
# 505/505 [==============================] - 377s 746ms/step - loss: 1.1842 - categorical_accuracy: 0.5546 - val_loss: 1.1429 - val_categorical_accuracy: 0.5809
# Epoch 96/100
# 505/505 [==============================] - 376s 744ms/step - loss: 1.1786 - categorical_accuracy: 0.5546 - val_loss: 1.1091 - val_categorical_accuracy: 0.5846
# Epoch 97/100
# 505/505 [==============================] - 406s 804ms/step - loss: 1.1761 - categorical_accuracy: 0.5570 - val_loss: 1.1062 - val_categorical_accuracy: 0.5804
# Epoch 98/100
# 505/505 [==============================] - 443s 877ms/step - loss: 1.1806 - categorical_accuracy: 0.5577 - val_loss: 1.1102 - val_categorical_accuracy: 0.5907
# Epoch 99/100
# 505/505 [==============================] - 442s 875ms/step - loss: 1.1713 - categorical_accuracy: 0.5608 - val_loss: 1.0814 - val_categorical_accuracy: 0.5979
# Epoch 100/100
# 505/505 [==============================] - 441s 873ms/step - loss: 1.1795 - categorical_accuracy: 0.5586 - val_loss: 1.0876 - val_categorical_accuracy: 0.5949

# %% [markdown]
# # FER+: Evaluation

# %%
plt.plot(model_log.history['categorical_accuracy'])
plt.plot(model_log.history['val_categorical_accuracy']);
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('epoch', size = 14)
plt.ylabel('Accuracy Score', size = 14)
plt.title('Categorical Accuracy', size = 16)
plt.show()

# %%
plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss']);
plt.legend(['Training Loss', 'Validation Loss'])
plt.xlabel('epoch', size = 14)
plt.ylabel('Loss', size = 14)
plt.title('Loss', size = 16)
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 113/113 [==============================] - 6s 57ms/step - loss: 1.0876 - categorical_accuracy: 0.5949
# [1.0875755548477173, 0.5948732495307922]

# %%
# Saves Validation predictions.
y_fer_unchanged = []
for idx, each in enumerate(y_test):
    y_fer_unchanged.append(np.argmax(each))

fer_prediction = model.predict_classes(X_test)

# %% [markdown]
# ## Confusion Matrix

# %%
# Plotting a confusion matrix.
fer_conf = tf.math.confusion_matrix(y_fer_unchanged, fer_prediction, num_classes = 7)

plt.figure(figsize = (10, 6))
plt.imshow(fer_conf, cmap = 'CMRmap')
plt.ylabel('True Labels')
plt.xlabel('Predictions')
plt.colorbar()

plt.show()

# %% [markdown]
# As we can observe from Confusion Matrix plotted for the CNN trained on a FER+ Dataset, the results are as unsatisfying as the previous model is.

# %%
model.save("fer_model_59.h5")
